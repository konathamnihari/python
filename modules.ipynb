# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with version '2.6.0', sqlite_version '3.42.0'
# C:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# IPython             argparse            jupyterlab_pygments sre_parse
# __future__          array               jupyterlab_server   ssl
# __hello__           arrow               jupyterlab_widgets  sspi
# __phello__          ast                 keyword             sspicon
# _abc                asttokens           lib2to3             stack_data
# _aix_support        async_lru           linecache           start_pythonwin
# _argon2_cffi_bindings asynchat            locale              stat
# _ast                asyncio             logging             statistics
# _asyncio            asyncore            lzma                string
# ...
